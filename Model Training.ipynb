# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\Machine learning\Machine Learning\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\data_banknote_authentication.csv")

# %%
df.head()
# Out:
#    Variance_Wavelet  Skewness_Wavelet  Curtosis_Wavelet  Image_Entropy  Class
# 0           3.62160            8.6661           -2.8073       -0.44699      0
# 1           4.54590            8.1674           -2.4586       -1.46210      0
# 2           3.86600           -2.6383            1.9242        0.10645      0
# 3           3.45660            9.5228           -4.0112       -3.59440      0
# 4           0.32924           -4.4552            4.5718       -0.98880      0

# %%
df[df['Class']==1]
# Out:
#       Variance_Wavelet  Skewness_Wavelet  Curtosis_Wavelet  Image_Entropy  \
# 762           -1.39710           3.31910         -1.392700       -1.99480
# 763            0.39012          -0.14279         -0.031994        0.35084
# 764           -1.66770          -7.15350          7.892900        0.96765
# 765           -3.84830         -12.80470         15.682400       -1.28100
# 766           -3.56810          -8.21300         10.083000        0.96765
# ...                ...               ...               ...            ...
# 1367           0.40614           1.34920         -1.450100       -0.55949
# 1368          -1.38870          -4.87730          6.477400        0.34179
# 1369          -3.75030         -13.45860         17.593200       -2.77710
# 1370          -3.56370          -8.38270         12.393000       -1.28230
# 1371          -2.54190          -0.65804          2.684200        1.19520
#
#       Class
# 762       1
# 763       1
# 764       1
# 765       1
# 766       1
# ...     ...
# 1367      1
# 1368      1
# 1369      1
# 1370      1
# 1371      1
#
# [610 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Variance_Wavelet    0
# Skewness_Wavelet    0
# Curtosis_Wavelet    0
# Image_Entropy       0
# Class               0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9927184466019418

# %%
import pickle
pickle_out = open("bank_classifier.pkl","wb")
pickle.dump(model,pickle_out)
pickle_out.close()

# %%
model.predict([[1,2,1,2]])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\Machine learning\\Machine Learning\\UNZIP_FOR_NOTEBOOKS_FINAL'

# %%
X_test.to_csv("X_test.csv",index=False)
